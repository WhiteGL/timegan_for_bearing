# %%
import numpy as np
import sys
import pandas as pd

# %%
sys.path.append('metrics')

from discriminative_score_metrics_v2 import discriminative_score_metrics
from visualization_metrics import PCA_Analysis, tSNE_Analysis
from predictive_score_metrics_v2 import predictive_score_metrics
from numerical_metrics import evaluate_all

# %%
dataX_hat = np.load('bearingX_hat_12-29.npy')
dataX = np.load('bearingX_12-29.npy')
dataY_hat = np.load('../bearing-data-synthetic/test_CNN_dis_LSTM_gen20_34.npy')
dataY_hat = np.reshape(dataY_hat, (608, 400))
dataY = pd.read_csv('./data/Norm1.csv')
datay = np.array(dataY['DE'])
data_true = np.zeros((608, 400))
for i in range(608):
    data_true[i] = datay[i*400:(i+1)*400]

# %%
PCA_Analysis (dataX, dataX_hat)

# %%
tSNE_Analysis (dataX, dataX_hat)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.000s...
# [t-SNE] Computed neighbors for 2000 samples in 0.079s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 0.507210
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.318115
# [t-SNE] KL divergence after 300 iterations: 2.631916

# %%
PCA_Analysis (data_true, dataY_hat)
tSNE_Analysis (data_true, dataY_hat)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-14-451d4f954c3e> in <module>()
# ----> 1 PCA_Analysis (data_true, dataY_hat)
#       2 tSNE_Analysis (data_true, dataY_hat)
#
# D:\python-project\timegan\metrics\visualization_metrics.py in PCA_Analysis(dataX, dataX_hat)
#      32     for i in range(Sample_No):
#      33         if (i == 0):
# ---> 34             arrayX = np.reshape(np.mean(np.asarray(dataX[0]), 1), [1, len(dataX[0][:, 0])])
#      35             arrayX_hat = np.reshape(np.mean(np.asarray(dataX_hat[0]), 1), [1, len(dataX[0][:, 0])])
#      36         else:
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# D:\Users\NINGMEI\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3371
#    3372     return _methods._mean(a, axis=axis, dtype=dtype,
# ...

# %%
res_tgan = evaluate_all(dataX, dataX_hat)

# %%
res_syn = evaluate_all(data_true, dataY_hat)

# %%
import numerical_metrics

# %%
y_tgan = []
y_syn = []
a = ['mape', 'gmrae', 'gmae', 'mrae', 'rmspe', 'std_ape', 'mpe', 'mre']
for item in numerical_metrics.METRICS:
    if item not in a:
        y_tgan.append(res_tgan[item])
        y_syn.append(res_syn[item])

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.plot(y_tgan,lw=2.5,label="tgan",color='blue')
plt.plot(y_syn,lw=2.5,label="syn",color='red')
plt.title("comparison",size=20,color='red')
plt.xlabel('item',size=20)
plt.ylabel('values',size=20)
# Out:
# Text(0, 0.5, 'values')
