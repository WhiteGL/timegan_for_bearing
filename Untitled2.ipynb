# %%
import tensorflow as tf
import numpy as np

tf.compat.v1.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From D:\Users\NINGMEI\Anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
saver = tf.compat.v1.train.import_meta_graph('D:/python-project/timegan/model/28-12-21_22_15.ckpt.meta')
graph_def = tf.compat.v1.get_default_graph().as_graph_def()
node_list=[n.name for n in graph_def.node]

# %%
node_list
# Out:
# ['myinput_x',
#  'myinput_z',
#  'myinput_t',
#  'embedder/rnn/Rank',
#  'embedder/rnn/range/start',
#  'embedder/rnn/range/delta',
#  'embedder/rnn/range',
#  'embedder/rnn/concat/values_0',
#  'embedder/rnn/concat/axis',
#  'embedder/rnn/concat',
#  'embedder/rnn/transpose',
#  'embedder/rnn/sequence_length',
#  'embedder/rnn/Shape',
#  'embedder/rnn/strided_slice/stack',
#  'embedder/rnn/strided_slice/stack_1',
#  'embedder/rnn/strided_slice/stack_2',
#  'embedder/rnn/strided_slice',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState/ExpandDims/dim',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState/ExpandDims',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState/Const',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState/concat/axis',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState/concat',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState/zeros/Const',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState/zeros',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState/ExpandDims_1/dim',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState/ExpandDims_1',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState/Const_1',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/ExpandDims/dim',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/ExpandDims',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/Const',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/concat/axis',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/concat',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/zeros/Const',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/zeros',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/ExpandDims_1/dim',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/ExpandDims_1',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/Const_1',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/ExpandDims/dim',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/ExpandDims',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/Const',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/concat/axis',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/concat',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/zeros/Const',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/zeros',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/ExpandDims_1/dim',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/ExpandDims_1',
#  'embedder/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/Const_1',
#  'embedder/rnn/Shape_1',
#  'embedder/rnn/stack',
#  'embedder/rnn/Equal',
#  'embedder/rnn/Const',
#  'embedder/rnn/All',
#  'embedder/rnn/Assert/Const',
#  'embedder/rnn/Assert/Const_1',
#  'embedder/rnn/Assert/Assert/data_0',
#  'embedder/rnn/Assert/Assert/data_2',
#  'embedder/rnn/Assert/Assert',
#  'embedder/rnn/CheckSeqLen',
#  'embedder/rnn/Shape_2',
#  'embedder/rnn/strided_slice_1/stack',
#  'embedder/rnn/strided_slice_1/stack_1',
#  'embedder/rnn/strided_slice_1/stack_2',
#  'embedder/rnn/strided_slice_1',
#  'embedder/rnn/Shape_3',
#  'embedder/rnn/strided_slice_2/stack',
#  'embedder/rnn/strided_slice_2/stack_1',
#  'embedder/rnn/strided_slice_2/stack_2',
#  'embedder/rnn/strided_slice_2',
#  'embedder/rnn/ExpandDims/dim',
#  'embedder/rnn/ExpandDims',
#  'embedder/rnn/Const_1',
#  'embedder/rnn/concat_1/axis',
#  'embedder/rnn/concat_1',
#  'embedder/rnn/zeros/Const',
#  'embedder/rnn/zeros',
#  'embedder/rnn/Const_2',
#  'embedder/rnn/Min',
#  'embedder/rnn/Const_3',
#  'embedder/rnn/Max',
#  'embedder/rnn/time',
#  'embedder/rnn/TensorArray',
#  'embedder/rnn/TensorArray_1',
#  'embedder/rnn/TensorArrayUnstack/Shape',
#  'embedder/rnn/TensorArrayUnstack/strided_slice/stack',
#  'embedder/rnn/TensorArrayUnstack/strided_slice/stack_1',
#  'embedder/rnn/TensorArrayUnstack/strided_slice/stack_2',
#  'embedder/rnn/TensorArrayUnstack/strided_slice',
#  'embedder/rnn/TensorArrayUnstack/range/start',
#  'embedder/rnn/TensorArrayUnstack/range/delta',
#  'embedder/rnn/TensorArrayUnstack/range',
#  'embedder/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3',
#  'embedder/rnn/Maximum/x',
#  'embedder/rnn/Maximum',
#  'embedder/rnn/Minimum',
#  'embedder/rnn/while/iteration_counter',
#  'embedder/rnn/while/Enter',
#  'embedder/rnn/while/Enter_1',
#  'embedder/rnn/while/Enter_2',
#  'embedder/rnn/while/Enter_3',
#  'embedder/rnn/while/Enter_4',
#  'embedder/rnn/while/Enter_5',
#  'embedder/rnn/while/Merge',
#  'embedder/rnn/while/Merge_1',
#  'embedder/rnn/while/Merge_2',
#  'embedder/rnn/while/Merge_3',
#  'embedder/rnn/while/Merge_4',
#  'embedder/rnn/while/Merge_5',
#  'embedder/rnn/while/Less/Enter',
#  'embedder/rnn/while/Less',
#  'embedder/rnn/while/Less_1/Enter',
#  'embedder/rnn/while/Less_1',
#  'embedder/rnn/while/LogicalAnd',
#  'embedder/rnn/while/LoopCond',
#  'embedder/rnn/while/Switch',
#  'embedder/rnn/while/Switch_1',
#  'embedder/rnn/while/Switch_2',
#  'embedder/rnn/while/Switch_3',
#  'embedder/rnn/while/Switch_4',
#  'embedder/rnn/while/Switch_5',
#  'embedder/rnn/while/Identity',
#  'embedder/rnn/while/Identity_1',
#  'embedder/rnn/while/Identity_2',
#  'embedder/rnn/while/Identity_3',
#  'embedder/rnn/while/Identity_4',
#  'embedder/rnn/while/Identity_5',
#  'embedder/rnn/while/add/y',
#  'embedder/rnn/while/add',
#  'embedder/rnn/while/TensorArrayReadV3/Enter',
#  'embedder/rnn/while/TensorArrayReadV3/Enter_1',
#  'embedder/rnn/while/TensorArrayReadV3',
#  'embedder/rnn/while/GreaterEqual/Enter',
#  'embedder/rnn/while/GreaterEqual',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/shape',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/min',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/max',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/RandomUniform',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/sub',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/mul',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/read',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/bias/Initializer/Const',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/bias',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/bias/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/gates/bias/read',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/shape',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/min',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/max',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/RandomUniform',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/sub',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/mul',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/read',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/bias/Initializer/zeros',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/bias',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/bias/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/bias/read',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/concat/axis',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/concat',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/MatMul/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/MatMul',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/BiasAdd/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/BiasAdd',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/Sigmoid',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/Const',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/split/split_dim',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/split',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/mul',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/concat_1/axis',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/concat_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/MatMul_1/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/MatMul_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/BiasAdd_1/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/BiasAdd_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/Tanh',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/mul_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/sub/x',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/sub',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/mul_2',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/add',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/shape',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/min',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/max',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/RandomUniform',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/sub',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/mul',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/read',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/bias/Initializer/Const',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/bias',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/bias/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/gates/bias/read',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/shape',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/min',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/max',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/RandomUniform',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/sub',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/mul',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/read',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/bias/Initializer/zeros',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/bias',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/bias/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/bias/read',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/concat/axis',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/concat',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/MatMul/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/MatMul',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/BiasAdd/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/BiasAdd',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/Sigmoid',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/Const',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/split/split_dim',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/split',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/mul',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/concat_1/axis',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/concat_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/MatMul_1/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/MatMul_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/BiasAdd_1/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/BiasAdd_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/Tanh',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/mul_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/sub/x',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/sub',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/mul_2',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/add',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/shape',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/min',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/max',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/RandomUniform',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/sub',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/mul',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/read',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/bias/Initializer/Const',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/bias',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/bias/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/gates/bias/read',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/shape',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/min',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/max',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/RandomUniform',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/sub',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/mul',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/read',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/bias/Initializer/zeros',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/bias',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/bias/Assign',
#  'embedder/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/bias/read',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/concat/axis',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/concat',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/MatMul/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/MatMul',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/BiasAdd/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/BiasAdd',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/Sigmoid',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/Const',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/split/split_dim',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/split',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/mul',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/concat_1/axis',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/concat_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/MatMul_1/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/MatMul_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/BiasAdd_1/Enter',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/BiasAdd_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/Tanh',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/mul_1',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/sub/x',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/sub',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/mul_2',
#  'embedder/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/add',
#  'embedder/rnn/while/Select/Enter',
#  'embedder/rnn/while/Select',
#  'embedder/rnn/while/Select_1',
#  'embedder/rnn/while/Select_2',
#  'embedder/rnn/while/Select_3',
#  'embedder/rnn/while/TensorArrayWrite/TensorArrayWriteV3/Enter',
#  'embedder/rnn/while/TensorArrayWrite/TensorArrayWriteV3',
#  'embedder/rnn/while/add_1/y',
#  'embedder/rnn/while/add_1',
#  'embedder/rnn/while/NextIteration',
#  'embedder/rnn/while/NextIteration_1',
#  'embedder/rnn/while/NextIteration_2',
#  'embedder/rnn/while/NextIteration_3',
#  'embedder/rnn/while/NextIteration_4',
#  'embedder/rnn/while/NextIteration_5',
#  'embedder/rnn/while/Exit',
#  'embedder/rnn/while/Exit_1',
#  'embedder/rnn/while/Exit_2',
#  'embedder/rnn/while/Exit_3',
#  'embedder/rnn/while/Exit_4',
#  'embedder/rnn/while/Exit_5',
#  'embedder/rnn/TensorArrayStack/range/start',
#  'embedder/rnn/TensorArrayStack/range/delta',
#  'embedder/rnn/TensorArrayStack/range',
#  'embedder/rnn/TensorArrayStack/TensorArrayGatherV3',
#  'embedder/rnn/Const_4',
#  'embedder/rnn/Rank_1',
#  'embedder/rnn/range_1/start',
#  'embedder/rnn/range_1/delta',
#  'embedder/rnn/range_1',
#  'embedder/rnn/concat_2/values_0',
#  'embedder/rnn/concat_2/axis',
#  'embedder/rnn/concat_2',
#  'embedder/rnn/transpose_1',
#  'embedder/dense/kernel/Initializer/random_uniform/shape',
#  'embedder/dense/kernel/Initializer/random_uniform/min',
#  'embedder/dense/kernel/Initializer/random_uniform/max',
#  'embedder/dense/kernel/Initializer/random_uniform/RandomUniform',
#  'embedder/dense/kernel/Initializer/random_uniform/sub',
#  'embedder/dense/kernel/Initializer/random_uniform/mul',
#  'embedder/dense/kernel/Initializer/random_uniform',
#  'embedder/dense/kernel',
#  'embedder/dense/kernel/Assign',
#  'embedder/dense/kernel/read',
#  'embedder/dense/bias/Initializer/zeros',
#  'embedder/dense/bias',
#  'embedder/dense/bias/Assign',
#  'embedder/dense/bias/read',
#  'embedder/dense/Tensordot/axes',
#  'embedder/dense/Tensordot/free',
#  'embedder/dense/Tensordot/Shape',
#  'embedder/dense/Tensordot/GatherV2/axis',
#  'embedder/dense/Tensordot/GatherV2',
#  'embedder/dense/Tensordot/GatherV2_1/axis',
#  'embedder/dense/Tensordot/GatherV2_1',
#  'embedder/dense/Tensordot/Const',
#  'embedder/dense/Tensordot/Prod',
#  'embedder/dense/Tensordot/Const_1',
#  'embedder/dense/Tensordot/Prod_1',
#  'embedder/dense/Tensordot/concat/axis',
#  'embedder/dense/Tensordot/concat',
#  'embedder/dense/Tensordot/stack',
#  'embedder/dense/Tensordot/transpose',
#  'embedder/dense/Tensordot/Reshape',
#  'embedder/dense/Tensordot/MatMul',
#  'embedder/dense/Tensordot/Const_2',
#  'embedder/dense/Tensordot/concat_1/axis',
#  'embedder/dense/Tensordot/concat_1',
#  'embedder/dense/Tensordot',
#  'embedder/dense/BiasAdd',
#  'embedder/dense/Sigmoid',
#  'recovery/rnn/Rank',
#  'recovery/rnn/range/start',
#  'recovery/rnn/range/delta',
#  'recovery/rnn/range',
#  'recovery/rnn/concat/values_0',
#  'recovery/rnn/concat/axis',
#  'recovery/rnn/concat',
#  'recovery/rnn/transpose',
#  'recovery/rnn/sequence_length',
#  'recovery/rnn/Shape',
#  'recovery/rnn/strided_slice/stack',
#  'recovery/rnn/strided_slice/stack_1',
#  'recovery/rnn/strided_slice/stack_2',
#  'recovery/rnn/strided_slice',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState/ExpandDims/dim',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState/ExpandDims',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState/Const',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState/concat/axis',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState/concat',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState/zeros/Const',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState/zeros',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState/ExpandDims_1/dim',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState/ExpandDims_1',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState/Const_1',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/ExpandDims/dim',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/ExpandDims',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/Const',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/concat/axis',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/concat',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/zeros/Const',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/zeros',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/ExpandDims_1/dim',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/ExpandDims_1',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_1/Const_1',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/ExpandDims/dim',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/ExpandDims',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/Const',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/concat/axis',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/concat',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/zeros/Const',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/zeros',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/ExpandDims_1/dim',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/ExpandDims_1',
#  'recovery/rnn/MultiRNNCellZeroState/GRUCellZeroState_2/Const_1',
#  'recovery/rnn/Shape_1',
#  'recovery/rnn/stack',
#  'recovery/rnn/Equal',
#  'recovery/rnn/Const',
#  'recovery/rnn/All',
#  'recovery/rnn/Assert/Const',
#  'recovery/rnn/Assert/Const_1',
#  'recovery/rnn/Assert/Assert/data_0',
#  'recovery/rnn/Assert/Assert/data_2',
#  'recovery/rnn/Assert/Assert',
#  'recovery/rnn/CheckSeqLen',
#  'recovery/rnn/Shape_2',
#  'recovery/rnn/strided_slice_1/stack',
#  'recovery/rnn/strided_slice_1/stack_1',
#  'recovery/rnn/strided_slice_1/stack_2',
#  'recovery/rnn/strided_slice_1',
#  'recovery/rnn/Shape_3',
#  'recovery/rnn/strided_slice_2/stack',
#  'recovery/rnn/strided_slice_2/stack_1',
#  'recovery/rnn/strided_slice_2/stack_2',
#  'recovery/rnn/strided_slice_2',
#  'recovery/rnn/ExpandDims/dim',
#  'recovery/rnn/ExpandDims',
#  'recovery/rnn/Const_1',
#  'recovery/rnn/concat_1/axis',
#  'recovery/rnn/concat_1',
#  'recovery/rnn/zeros/Const',
#  'recovery/rnn/zeros',
#  'recovery/rnn/Const_2',
#  'recovery/rnn/Min',
#  'recovery/rnn/Const_3',
#  'recovery/rnn/Max',
#  'recovery/rnn/time',
#  'recovery/rnn/TensorArray',
#  'recovery/rnn/TensorArray_1',
#  'recovery/rnn/TensorArrayUnstack/Shape',
#  'recovery/rnn/TensorArrayUnstack/strided_slice/stack',
#  'recovery/rnn/TensorArrayUnstack/strided_slice/stack_1',
#  'recovery/rnn/TensorArrayUnstack/strided_slice/stack_2',
#  'recovery/rnn/TensorArrayUnstack/strided_slice',
#  'recovery/rnn/TensorArrayUnstack/range/start',
#  'recovery/rnn/TensorArrayUnstack/range/delta',
#  'recovery/rnn/TensorArrayUnstack/range',
#  'recovery/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3',
#  'recovery/rnn/Maximum/x',
#  'recovery/rnn/Maximum',
#  'recovery/rnn/Minimum',
#  'recovery/rnn/while/iteration_counter',
#  'recovery/rnn/while/Enter',
#  'recovery/rnn/while/Enter_1',
#  'recovery/rnn/while/Enter_2',
#  'recovery/rnn/while/Enter_3',
#  'recovery/rnn/while/Enter_4',
#  'recovery/rnn/while/Enter_5',
#  'recovery/rnn/while/Merge',
#  'recovery/rnn/while/Merge_1',
#  'recovery/rnn/while/Merge_2',
#  'recovery/rnn/while/Merge_3',
#  'recovery/rnn/while/Merge_4',
#  'recovery/rnn/while/Merge_5',
#  'recovery/rnn/while/Less/Enter',
#  'recovery/rnn/while/Less',
#  'recovery/rnn/while/Less_1/Enter',
#  'recovery/rnn/while/Less_1',
#  'recovery/rnn/while/LogicalAnd',
#  'recovery/rnn/while/LoopCond',
#  'recovery/rnn/while/Switch',
#  'recovery/rnn/while/Switch_1',
#  'recovery/rnn/while/Switch_2',
#  'recovery/rnn/while/Switch_3',
#  'recovery/rnn/while/Switch_4',
#  'recovery/rnn/while/Switch_5',
#  'recovery/rnn/while/Identity',
#  'recovery/rnn/while/Identity_1',
#  'recovery/rnn/while/Identity_2',
#  'recovery/rnn/while/Identity_3',
#  'recovery/rnn/while/Identity_4',
#  'recovery/rnn/while/Identity_5',
#  'recovery/rnn/while/add/y',
#  'recovery/rnn/while/add',
#  'recovery/rnn/while/TensorArrayReadV3/Enter',
#  'recovery/rnn/while/TensorArrayReadV3/Enter_1',
#  'recovery/rnn/while/TensorArrayReadV3',
#  'recovery/rnn/while/GreaterEqual/Enter',
#  'recovery/rnn/while/GreaterEqual',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/shape',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/min',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/max',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/RandomUniform',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/sub',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform/mul',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Initializer/random_uniform',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/kernel/read',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/bias/Initializer/Const',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/bias',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/bias/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/gates/bias/read',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/shape',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/min',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/max',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/RandomUniform',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/sub',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform/mul',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Initializer/random_uniform',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/kernel/read',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/bias/Initializer/zeros',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/bias',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/bias/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_0/gru_cell/candidate/bias/read',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/concat/axis',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/concat',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/MatMul/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/MatMul',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/BiasAdd/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/BiasAdd',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/Sigmoid',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/Const',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/split/split_dim',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/split',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/mul',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/concat_1/axis',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/concat_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/MatMul_1/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/MatMul_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/BiasAdd_1/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/BiasAdd_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/Tanh',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/mul_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/sub/x',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/sub',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/mul_2',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_0/gru_cell/add',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/shape',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/min',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/max',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/RandomUniform',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/sub',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform/mul',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Initializer/random_uniform',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/kernel/read',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/bias/Initializer/Const',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/bias',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/bias/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/gates/bias/read',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/shape',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/min',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/max',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/RandomUniform',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/sub',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform/mul',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Initializer/random_uniform',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/kernel/read',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/bias/Initializer/zeros',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/bias',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/bias/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_1/gru_cell/candidate/bias/read',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/concat/axis',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/concat',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/MatMul/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/MatMul',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/BiasAdd/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/BiasAdd',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/Sigmoid',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/Const',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/split/split_dim',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/split',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/mul',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/concat_1/axis',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/concat_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/MatMul_1/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/MatMul_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/BiasAdd_1/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/BiasAdd_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/Tanh',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/mul_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/sub/x',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/sub',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/mul_2',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_1/gru_cell/add',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/shape',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/min',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/max',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/RandomUniform',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/sub',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform/mul',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Initializer/random_uniform',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/kernel/read',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/bias/Initializer/Const',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/bias',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/bias/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/gates/bias/read',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/shape',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/min',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/max',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/RandomUniform',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/sub',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform/mul',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Initializer/random_uniform',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/kernel/read',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/bias/Initializer/zeros',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/bias',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/bias/Assign',
#  'recovery/rnn/multi_rnn_cell/cell_2/gru_cell/candidate/bias/read',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/concat/axis',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/concat',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/MatMul/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/MatMul',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/BiasAdd/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/BiasAdd',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/Sigmoid',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/Const',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/split/split_dim',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/split',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/mul',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/concat_1/axis',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/concat_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/MatMul_1/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/MatMul_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/BiasAdd_1/Enter',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/BiasAdd_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/Tanh',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/mul_1',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/sub/x',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/sub',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/mul_2',
#  'recovery/rnn/while/rnn/multi_rnn_cell/cell_2/gru_cell/add',
#  'recovery/rnn/while/Select/Enter',
#  'recovery/rnn/while/Select',
#  'recovery/rnn/while/Select_1',
#  'recovery/rnn/while/Select_2',
#  'recovery/rnn/while/Select_3',
#  'recovery/rnn/while/TensorArrayWrite/TensorArrayWriteV3/Enter',
#  'recovery/rnn/while/TensorArrayWrite/TensorArrayWriteV3',
#  'recovery/rnn/while/add_1/y',
#  'recovery/rnn/while/add_1',
#  'recovery/rnn/while/NextIteration',
#  'recovery/rnn/while/NextIteration_1',
#  'recovery/rnn/while/NextIteration_2',
#  'recovery/rnn/while/NextIteration_3',
#  'recovery/rnn/while/NextIteration_4',
#  'recovery/rnn/while/NextIteration_5',
#  'recovery/rnn/while/Exit',
#  'recovery/rnn/while/Exit_1',
#  'recovery/rnn/while/Exit_2',
#  'recovery/rnn/while/Exit_3',
#  'recovery/rnn/while/Exit_4',
#  'recovery/rnn/while/Exit_5',
#  'recovery/rnn/TensorArrayStack/range/start',
#  'recovery/rnn/TensorArrayStack/range/delta',
#  'recovery/rnn/TensorArrayStack/range',
#  'recovery/rnn/TensorArrayStack/TensorArrayGatherV3',
#  'recovery/rnn/Const_4',
#  'recovery/rnn/Rank_1',
#  'recovery/rnn/range_1/start',
#  'recovery/rnn/range_1/delta',
#  'recovery/rnn/range_1',
#  'recovery/rnn/concat_2/values_0',
#  'recovery/rnn/concat_2/axis',
#  'recovery/rnn/concat_2',
#  'recovery/rnn/transpose_1',
#  'recovery/dense/kernel/Initializer/random_uniform/shape',
#  'recovery/dense/kernel/Initializer/random_uniform/min',
#  'recovery/dense/kernel/Initializer/random_uniform/max',
#  'recovery/dense/kernel/Initializer/random_uniform/RandomUniform',
#  'recovery/dense/kernel/Initializer/random_uniform/sub',
#  'recovery/dense/kernel/Initializer/random_uniform/mul',
#  'recovery/dense/kernel/Initializer/random_uniform',
#  'recovery/dense/kernel',
#  'recovery/dense/kernel/Assign',
#  'recovery/dense/kernel/read',
#  'recovery/dense/bias/Initializer/zeros',
#  'recovery/dense/bias',
#  'recovery/dense/bias/Assign',
#  'recovery/dense/bias/read',
#  'recovery/dense/Tensordot/axes',
#  'recovery/dense/Tensordot/free',
#  'recovery/dense/Tensordot/Shape',
#  'recovery/dense/Tensordot/GatherV2/axis',
#  'recovery/dense/Tensordot/GatherV2',
#  'recovery/dense/Tensordot/GatherV2_1/axis',
#  'recovery/dense/Tensordot/GatherV2_1',
#  'recovery/dense/Tensordot/Const',
#  'recovery/dense/Tensordot/Prod',
#  'recovery/dense/Tensordot/Const_1',
#  'recovery/dense/Tensordot/Prod_1',
#  'recovery/dense/Tensordot/concat/axis',
#  'recovery/dense/Tensordot/concat',
#  'recovery/dense/Tensordot/stack',
#  'recovery/dense/Tensordot/transpose',
#  'recovery/dense/Tensordot/Reshape',
#  'recovery/dense/Tensordot/MatMul',
#  'recovery/dense/Tensordot/Const_2',
#  'recovery/dense/Tensordot/concat_1/axis',
#  'recovery/dense/Tensordot/concat_1',
#  'recovery/dense/Tensordot',
#  'recovery/dense/BiasAdd',
#  'recovery/dense/Sigmoid',
#  'generator/rnn/Rank',
#  'generator/rnn/range/start',
#  'generator/rnn/range/delta',
#  'generator/rnn/range',
#  'generator/rnn/concat/values_0',
#  'generator/rnn/concat/axis',
#  'generator/rnn/concat',
#  'generator/rnn/transpose',
#  'generator/rnn/sequence_length',
#  'generator/rnn/Shape',
#  'generator/rnn/strided_slice/stack',
#  'generator/rnn/strided_slice/stack_1',
#  'generator/rnn/strided_slice/stack_2',
#  'generator/rnn/strided_slice',
#  'generator/rnn/GRUCellZeroState/ExpandDims/dim',
#  'generator/rnn/GRUCellZeroState/ExpandDims',
#  'generator/rnn/GRUCellZeroState/Const',
#  'generator/rnn/GRUCellZeroState/concat/axis',
#  'generator/rnn/GRUCellZeroState/concat',
#  'generator/rnn/GRUCellZeroState/zeros/Const',
#  'generator/rnn/GRUCellZeroState/zeros',
#  'generator/rnn/GRUCellZeroState/ExpandDims_1/dim',
#  'generator/rnn/GRUCellZeroState/ExpandDims_1',
#  'generator/rnn/GRUCellZeroState/Const_1',
#  'generator/rnn/GRUCellZeroState_1/ExpandDims/dim',
#  'generator/rnn/GRUCellZeroState_1/ExpandDims',
#  'generator/rnn/GRUCellZeroState_1/Const',
#  'generator/rnn/GRUCellZeroState_1/concat/axis',
#  'generator/rnn/GRUCellZeroState_1/concat',
#  'generator/rnn/GRUCellZeroState_1/zeros/Const',
#  'generator/rnn/GRUCellZeroState_1/zeros',
#  'generator/rnn/GRUCellZeroState_1/ExpandDims_1/dim',
#  'generator/rnn/GRUCellZeroState_1/ExpandDims_1',
#  'generator/rnn/GRUCellZeroState_1/Const_1',
#  'generator/rnn/GRUCellZeroState_2/ExpandDims/dim',
#  'generator/rnn/GRUCellZeroState_2/ExpandDims',
#  'generator/rnn/GRUCellZeroState_2/Const',
#  'generator/rnn/GRUCellZeroState_2/concat/axis',
#  'generator/rnn/GRUCellZeroState_2/concat',
#  'generator/rnn/GRUCellZeroState_2/zeros/Const',
#  'generator/rnn/GRUCellZeroState_2/zeros',
#  'generator/rnn/GRUCellZeroState_2/ExpandDims_1/dim',
#  'generator/rnn/GRUCellZeroState_2/ExpandDims_1',
#  'generator/rnn/GRUCellZeroState_2/Const_1',
#  'generator/rnn/Shape_1',
#  'generator/rnn/stack',
#  'generator/rnn/Equal',
#  'generator/rnn/Const',
#  'generator/rnn/All',
#  'generator/rnn/Assert/Const',
#  'generator/rnn/Assert/Const_1',
#  'generator/rnn/Assert/Assert/data_0',
#  'generator/rnn/Assert/Assert/data_2',
#  'generator/rnn/Assert/Assert',
#  'generator/rnn/CheckSeqLen',
#  'generator/rnn/Shape_2',
#  'generator/rnn/strided_slice_1/stack',
#  'generator/rnn/strided_slice_1/stack_1',
#  'generator/rnn/strided_slice_1/stack_2',
#  'generator/rnn/strided_slice_1',
#  'generator/rnn/Shape_3',
#  'generator/rnn/strided_slice_2/stack',
#  'generator/rnn/strided_slice_2/stack_1',
#  'generator/rnn/strided_slice_2/stack_2',
#  'generator/rnn/strided_slice_2',
#  'generator/rnn/ExpandDims/dim',
#  'generator/rnn/ExpandDims',
#  'generator/rnn/Const_1',
#  'generator/rnn/concat_1/axis',
#  'generator/rnn/concat_1',
#  'generator/rnn/zeros/Const',
#  'generator/rnn/zeros',
#  'generator/rnn/Const_2',
#  'generator/rnn/Min',
#  'generator/rnn/Const_3',
#  'generator/rnn/Max',
#  'generator/rnn/time',
#  'generator/rnn/TensorArray',
#  'generator/rnn/TensorArray_1',
#  'generator/rnn/TensorArrayUnstack/Shape',
#  'generator/rnn/TensorArrayUnstack/strided_slice/stack',
#  'generator/rnn/TensorArrayUnstack/strided_slice/stack_1',
#  'generator/rnn/TensorArrayUnstack/strided_slice/stack_2',
#  'generator/rnn/TensorArrayUnstack/strided_slice',
#  'generator/rnn/TensorArrayUnstack/range/start',
#  'generator/rnn/TensorArrayUnstack/range/delta',
#  'generator/rnn/TensorArrayUnstack/range',
#  'generator/rnn/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3',
#  'generator/rnn/Maximum/x',
#  'generator/rnn/Maximum',
#  'generator/rnn/Minimum',
#  'generator/rnn/while/iteration_counter',
#  'generator/rnn/while/Enter',
#  'generator/rnn/while/Enter_1',
#  'generator/rnn/while/Enter_2',
#  'generator/rnn/while/Enter_3',
#  'generator/rnn/while/Enter_4',
#  'generator/rnn/while/Enter_5',
#  'generator/rnn/while/Merge',
#  'generator/rnn/while/Merge_1',
#  'generator/rnn/while/Merge_2',
#  'generator/rnn/while/Merge_3',
#  'generator/rnn/while/Merge_4',
#  'generator/rnn/while/Merge_5',
#  'generator/rnn/while/Less/Enter',
#  'generator/rnn/while/Less',
#  'generator/rnn/while/Less_1/Enter',
#  'generator/rnn/while/Less_1',
#  'generator/rnn/while/LogicalAnd',
#  'generator/rnn/while/LoopCond',
#  'generator/rnn/while/Switch',
#  'generator/rnn/while/Switch_1',
#  'generator/rnn/while/Switch_2',
#  'generator/rnn/while/Switch_3',
#  'generator/rnn/while/Switch_4',
#  'generator/rnn/while/Switch_5',
#  'generator/rnn/while/Identity',
#  'generator/rnn/while/Identity_1',
#  'generator/rnn/while/Identity_2',
#  'generator/rnn/while/Identity_3',
#  'generator/rnn/while/Identity_4',
#  'generator/rnn/while/Identity_5',
#  'generator/rnn/while/add/y',
#  'generator/rnn/while/add',
#  'generator/rnn/while/TensorArrayReadV3/Enter',
#  'generator/rnn/while/TensorArrayReadV3/Enter_1',
#  'generator/rnn/while/TensorArrayReadV3',
#  'generator/rnn/while/GreaterEqual/Enter',
#  'generator/rnn/while/GreaterEqual',
#  'generator/rnn/gru_cell/gates/kernel/Initializer/random_uniform/shape',
#  'generator/rnn/gru_cell/gates/kernel/Initializer/random_uniform/min',
#  'generator/rnn/gru_cell/gates/kernel/Initializer/random_uniform/max',
#  'generator/rnn/gru_cell/gates/kernel/Initializer/random_uniform/RandomUniform',
#  'generator/rnn/gru_cell/gates/kernel/Initializer/random_uniform/sub',
#  'generator/rnn/gru_cell/gates/kernel/Initializer/random_uniform/mul',
#  'generator/rnn/gru_cell/gates/kernel/Initializer/random_uniform',
#  'generator/rnn/gru_cell/gates/kernel',
#  'generator/rnn/gru_cell/gates/kernel/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell/gates/kernel/Assign',
#  'generator/rnn/gru_cell/gates/kernel/Read/ReadVariableOp',
#  'generator/rnn/gru_cell/gates/kernel/Read/Identity',
#  'generator/rnn/gru_cell/gates/bias/Initializer/Const',
#  'generator/rnn/gru_cell/gates/bias',
#  'generator/rnn/gru_cell/gates/bias/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell/gates/bias/Assign',
#  'generator/rnn/gru_cell/gates/bias/Read/ReadVariableOp',
#  'generator/rnn/gru_cell/gates/bias/Read/Identity',
#  'generator/rnn/gru_cell/candidate/kernel/Initializer/random_uniform/shape',
#  'generator/rnn/gru_cell/candidate/kernel/Initializer/random_uniform/min',
#  'generator/rnn/gru_cell/candidate/kernel/Initializer/random_uniform/max',
#  'generator/rnn/gru_cell/candidate/kernel/Initializer/random_uniform/RandomUniform',
#  'generator/rnn/gru_cell/candidate/kernel/Initializer/random_uniform/sub',
#  'generator/rnn/gru_cell/candidate/kernel/Initializer/random_uniform/mul',
#  'generator/rnn/gru_cell/candidate/kernel/Initializer/random_uniform',
#  'generator/rnn/gru_cell/candidate/kernel',
#  'generator/rnn/gru_cell/candidate/kernel/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell/candidate/kernel/Assign',
#  'generator/rnn/gru_cell/candidate/kernel/Read/ReadVariableOp',
#  'generator/rnn/gru_cell/candidate/kernel/Read/Identity',
#  'generator/rnn/gru_cell/candidate/bias/Initializer/zeros',
#  'generator/rnn/gru_cell/candidate/bias',
#  'generator/rnn/gru_cell/candidate/bias/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell/candidate/bias/Assign',
#  'generator/rnn/gru_cell/candidate/bias/Read/ReadVariableOp',
#  'generator/rnn/gru_cell/candidate/bias/Read/Identity',
#  'generator/rnn/gru_cell_1/gates/kernel/Initializer/random_uniform/shape',
#  'generator/rnn/gru_cell_1/gates/kernel/Initializer/random_uniform/min',
#  'generator/rnn/gru_cell_1/gates/kernel/Initializer/random_uniform/max',
#  'generator/rnn/gru_cell_1/gates/kernel/Initializer/random_uniform/RandomUniform',
#  'generator/rnn/gru_cell_1/gates/kernel/Initializer/random_uniform/sub',
#  'generator/rnn/gru_cell_1/gates/kernel/Initializer/random_uniform/mul',
#  'generator/rnn/gru_cell_1/gates/kernel/Initializer/random_uniform',
#  'generator/rnn/gru_cell_1/gates/kernel',
#  'generator/rnn/gru_cell_1/gates/kernel/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell_1/gates/kernel/Assign',
#  'generator/rnn/gru_cell_1/gates/kernel/Read/ReadVariableOp',
#  'generator/rnn/gru_cell_1/gates/kernel/Read/Identity',
#  'generator/rnn/gru_cell_1/gates/bias/Initializer/Const',
#  'generator/rnn/gru_cell_1/gates/bias',
#  'generator/rnn/gru_cell_1/gates/bias/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell_1/gates/bias/Assign',
#  'generator/rnn/gru_cell_1/gates/bias/Read/ReadVariableOp',
#  'generator/rnn/gru_cell_1/gates/bias/Read/Identity',
#  'generator/rnn/gru_cell_1/candidate/kernel/Initializer/random_uniform/shape',
#  'generator/rnn/gru_cell_1/candidate/kernel/Initializer/random_uniform/min',
#  'generator/rnn/gru_cell_1/candidate/kernel/Initializer/random_uniform/max',
#  'generator/rnn/gru_cell_1/candidate/kernel/Initializer/random_uniform/RandomUniform',
#  'generator/rnn/gru_cell_1/candidate/kernel/Initializer/random_uniform/sub',
#  'generator/rnn/gru_cell_1/candidate/kernel/Initializer/random_uniform/mul',
#  'generator/rnn/gru_cell_1/candidate/kernel/Initializer/random_uniform',
#  'generator/rnn/gru_cell_1/candidate/kernel',
#  'generator/rnn/gru_cell_1/candidate/kernel/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell_1/candidate/kernel/Assign',
#  'generator/rnn/gru_cell_1/candidate/kernel/Read/ReadVariableOp',
#  'generator/rnn/gru_cell_1/candidate/kernel/Read/Identity',
#  'generator/rnn/gru_cell_1/candidate/bias/Initializer/zeros',
#  'generator/rnn/gru_cell_1/candidate/bias',
#  'generator/rnn/gru_cell_1/candidate/bias/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell_1/candidate/bias/Assign',
#  'generator/rnn/gru_cell_1/candidate/bias/Read/ReadVariableOp',
#  'generator/rnn/gru_cell_1/candidate/bias/Read/Identity',
#  'generator/rnn/gru_cell_2/gates/kernel/Initializer/random_uniform/shape',
#  'generator/rnn/gru_cell_2/gates/kernel/Initializer/random_uniform/min',
#  'generator/rnn/gru_cell_2/gates/kernel/Initializer/random_uniform/max',
#  'generator/rnn/gru_cell_2/gates/kernel/Initializer/random_uniform/RandomUniform',
#  'generator/rnn/gru_cell_2/gates/kernel/Initializer/random_uniform/sub',
#  'generator/rnn/gru_cell_2/gates/kernel/Initializer/random_uniform/mul',
#  'generator/rnn/gru_cell_2/gates/kernel/Initializer/random_uniform',
#  'generator/rnn/gru_cell_2/gates/kernel',
#  'generator/rnn/gru_cell_2/gates/kernel/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell_2/gates/kernel/Assign',
#  'generator/rnn/gru_cell_2/gates/kernel/Read/ReadVariableOp',
#  'generator/rnn/gru_cell_2/gates/kernel/Read/Identity',
#  'generator/rnn/gru_cell_2/gates/bias/Initializer/Const',
#  'generator/rnn/gru_cell_2/gates/bias',
#  'generator/rnn/gru_cell_2/gates/bias/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell_2/gates/bias/Assign',
#  'generator/rnn/gru_cell_2/gates/bias/Read/ReadVariableOp',
#  'generator/rnn/gru_cell_2/gates/bias/Read/Identity',
#  'generator/rnn/gru_cell_2/candidate/kernel/Initializer/random_uniform/shape',
#  'generator/rnn/gru_cell_2/candidate/kernel/Initializer/random_uniform/min',
#  'generator/rnn/gru_cell_2/candidate/kernel/Initializer/random_uniform/max',
#  'generator/rnn/gru_cell_2/candidate/kernel/Initializer/random_uniform/RandomUniform',
#  'generator/rnn/gru_cell_2/candidate/kernel/Initializer/random_uniform/sub',
#  'generator/rnn/gru_cell_2/candidate/kernel/Initializer/random_uniform/mul',
#  'generator/rnn/gru_cell_2/candidate/kernel/Initializer/random_uniform',
#  'generator/rnn/gru_cell_2/candidate/kernel',
#  'generator/rnn/gru_cell_2/candidate/kernel/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell_2/candidate/kernel/Assign',
#  'generator/rnn/gru_cell_2/candidate/kernel/Read/ReadVariableOp',
#  'generator/rnn/gru_cell_2/candidate/kernel/Read/Identity',
#  'generator/rnn/gru_cell_2/candidate/bias/Initializer/zeros',
#  'generator/rnn/gru_cell_2/candidate/bias',
#  'generator/rnn/gru_cell_2/candidate/bias/IsInitialized/VarIsInitializedOp',
#  'generator/rnn/gru_cell_2/candidate/bias/Assign',
#  'generator/rnn/gru_cell_2/candidate/bias/Read/ReadVariableOp',
#  'generator/rnn/gru_cell_2/candidate/bias/Read/Identity',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/concat/axis',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/concat',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/MatMul/Enter',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/MatMul',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/BiasAdd/Enter',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/BiasAdd',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/Sigmoid',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/Const',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/split/split_dim',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/split',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/mul',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/concat_1/axis',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/concat_1',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/MatMul_1/Enter',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/MatMul_1',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/BiasAdd_1/Enter',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/BiasAdd_1',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/Tanh',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/mul_1',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/sub/x',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/sub',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/mul_2',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_7/gru_cell/add',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/concat/axis',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/concat',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/MatMul/Enter',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/MatMul',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/BiasAdd/Enter',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/BiasAdd',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/Sigmoid',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/Const',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/split/split_dim',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/split',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/mul',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/concat_1/axis',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/concat_1',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/MatMul_1/Enter',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/MatMul_1',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/BiasAdd_1/Enter',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/BiasAdd_1',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/Tanh',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/mul_1',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/sub/x',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/sub',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/mul_2',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_8/gru_cell/add',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_9/gru_cell/concat/axis',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_9/gru_cell/concat',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_9/gru_cell/MatMul/Enter',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_9/gru_cell/MatMul',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_9/gru_cell/BiasAdd/Enter',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_9/gru_cell/BiasAdd',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_9/gru_cell/Sigmoid',
#  'generator/rnn/while/stacked_rnn_cells/gru_cell_9/gru_cell/Const',
#  ...]
